# %% [markdown]
# # Math 449 Homework 1
# ## Wenzhen Zhu
# ### 445518

# %%
from __future__ import division
from pylab import *

def heronStep(y, x):
    """Perform one step of Heron's method for sqrt(y) with guess x."""
    return 0.5*(x + y/x)

def heronArray(y, x0, n):
    """Perform n steps of Heron's method for sqrt(y) with initial guess x0.
    Return the array of successive approximations [x0, x1, ..., xn]."""
    x = zeros(n+1)
    x[0] = x0
    for k in range(n):
        x[k+1] = heronStep(y, x[k])
    return x

def plotLogError(y, x0, n):
    """Plot the log absolute error of Heron's method."""
    x = heronArray(y, x0, n) # Heron's method approximations for sqrt(y)
    e = x - sqrt(y) # error
    semilogy(abs(e)) # plot abs(e) using a log scale for the y-axis

# %% [markdown]
# ### Problem 3
# Starting with x0 = 1, how many iterations n of Heron's method are needed so that xn = sqrt(2) is correct to 6 decimal places? What about p0?

# %%
heronArray(2, 1, 4)
# Out:
# array([ 1.        ,  1.5       ,  1.41666667,  1.41421569,  1.41421356])

# %% [markdown]
# when y = 2, it takes 4 iterations to be correct to 6 decimal places

# %%
heronArray(0, 1, 20)
# Out:
# array([  1.00000000e+00,   5.00000000e-01,   2.50000000e-01,
#          1.25000000e-01,   6.25000000e-02,   3.12500000e-02,
#          1.56250000e-02,   7.81250000e-03,   3.90625000e-03,
#          1.95312500e-03,   9.76562500e-04,   4.88281250e-04,
#          2.44140625e-04,   1.22070312e-04,   6.10351562e-05,
#          3.05175781e-05,   1.52587891e-05,   7.62939453e-06,
#          3.81469727e-06,   1.90734863e-06,   9.53674316e-07])

# %% [markdown]
# when y = 0, it takes 20 iterations to be correct.

# %% [markdown]
# ### Problem 4
# The function plotLogError plots log|xk − √y| for Heron’s method.
#
# Look at the cases y = 2, 3 when x0 = 1. For each of these plots, you should notice that something strange happens after a few steps. Can you explain the observed behavior?

# %%
show(plotLogError(2,1,10),plotLogError(3,1,10))

# %% [markdown]
# ### Problem 5

# %%
heronArray(-1,1,2)
# Out:
# /Users/wenzhen/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in double_scalars
# array([  1.,   0., -inf])

# %% [markdown]
# When y = -1, x1 = 0, x2 = -infinity, because x1 = 0, which cannot be a divider.

# %%
list1 = heronArray(-2, 1, 100)
show(plot(list1))

# %% [markdown]
# when y = -2, x_k is like random walk

# %%
list2 = heronArray(-3, 1, 10)
show(plot(list2))

# %% [markdown]
# when y = -3, the sequence is oscillating series 1 or -1

# %% [markdown]
# ### Problem 6

# %%
def cosArray(x0, n):
    x = zeros(n+1)
    x[0] = x0
    for k in range(n):
        x[k+1] = math.cos(x[k])
    return x

# %%
plt=plot(cosArray(1,40))
show(plt)

# %% [markdown]
# The fixed point is at 0.739085
